# %% [markdown]
# ## Data Analysis

# %%
import pandas as pd

# %%
# 2 Main Datatypes 

series = pd.Series(["BMW", "TATA"])

# %%
series
# Out:
# 0     BMW
# 1    TATA
# dtype: object

# %%
# series => 1-dimentional

# %%
colours = pd.Series(['RED', 'BLUE', 'WHITE', 'BLACK'])

# %%
colours
# Out:
# 0      RED
# 1     BLUE
# 2    WHITE
# 3    BLACK
# dtype: object

# %%
# DataFrames => 2-dimentional

# %%
car_data = pd.DataFrame({"Car Make": series, "Colors": colours})

# %%
car_data
# Out:
#   Car Make Colors
# 0      BMW    RED
# 1     TATA   BLUE
# 2      NaN  WHITE
# 3      NaN  BLACK

# %%
# Import Data: from the .csv file

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Exporting the data: to .csv | Adding the index as false

# %%
car_sales.to_csv("exporting-car-sales.csv", index=False)

# %%
# Reading the exported data

# %%
exported_car_sales = pd.read_csv("exporting-car-sales.csv")

# %%
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Reading the data from url.csv

# %%
url_csv_data = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv")

# %%
url_csv_data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
# Exporting the url csv data locally

# %%
url_csv_data.to_csv("export_url_csv_data.csv", index=False)

# %%
# Reading the url csv exported data

# %%
url_exported_data = pd.read_csv("export_url_csv_data.csv")

# %%
url_exported_data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
print(url_exported_data.head())
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# ## Describe Data

# %%
# Attribute (represents the meta information stored about the object)
car_sales.dtypes

# Function (that can perform  certian actions)
# car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe
# Out:
# <bound method NDFrame.describe of      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00>

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info
# Out:
# <bound method DataFrame.info of      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00>

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales.mean
# Out:
# <bound method DataFrame.mean of      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00>

# %%
car_doors_mean = pd.Series(car_sales.Doors)
car_doors_mean
# Out:
# 0    4
# 1    4
# 2    3
# 3    5
# 4    4
# 5    4
# 6    4
# 7    4
# 8    4
# 9    4
# Name: Doors, dtype: int64

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## Viewing and Selecting Data

# %%
# Returns top 5 data from the top

car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(10)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#Returns top 5 data from bottom 

car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.tail(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# .loc and .iloc 

animals = pd.Series(["CAT", "DOG", "WOLF", "LION", "SNAKE"], 
                   index=[0, 2, 4, 6, 2])

animals
# Out:
# 0      CAT
# 2      DOG
# 4     WOLF
# 6     LION
# 2    SNAKE
# dtype: object

# %%
# .loc (refers to the locaiton of the data)

animals.loc[2]
# Out:
# 2      DOG
# 2    SNAKE
# dtype: object

# %%
animals.loc[4]
# Out:
# 'WOLF'

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals
# Out:
# 0      CAT
# 2      DOG
# 4     WOLF
# 6     LION
# 2    SNAKE
# dtype: object

# %%
# .iloc (refers to the position of the data)

animals.iloc[2]
# Out:
# 'WOLF'

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
### with .loc and .iloc, you can also perform the slicing. 

### Like - 

print(f"Car Sales Slice: .loc \n {car_sales.loc[:3]}") 
print(f"Car Sales Slice: .iloc \n {car_sales.iloc[:4]}")
# Out:
# Car Sales Slice: .loc
#       Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# Car Sales Slice: .iloc
#       Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales[car_sales["Odometer (KM)"] >= 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
# Cross data comparison between two columns of the data table

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Cross data comparison: crosstab 

pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Groupby: compare more columns in content of another column

# %%
car_sales.groupby(["Make"]).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Documents/Personal/DATA-ANALYSIS-ML-AI/Data-Analysis-ML-AI/da_env/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~/Documents/Personal/DATA-ANALYSIS-ML-AI/Data-Analysis-ML-AI/da_env/lib/python3.12/site-packages/pandas/core/groupby/ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# ...

# %%
import matplotlib.pyplot as plt

# %% [raw]
# conda install matplotlib

# %%
conda install matplotlib
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"]).plot()
# Out:
#   Cell In[69], line 1
#     car_sales["Odometer (KM)"]).plot()
#                               ^
# SyntaxError: unmatched ')'

# %%
car_sales["Odometer (KM)"].hist()

# %%
car_sales["Odometer (KM)"].info
# Out:
# <bound method Series.info of 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64>

# %%
car_sales["Odometer (KM)"].dtype
# Out:
# dtype('int64')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '').astyp(int)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# /tmp/ipykernel_35419/1081645196.py:1: SyntaxWarning: invalid escape sequence '\$'
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '').astyp(int)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_35419/1081645196.py in ?()
# ----> 1 car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '').astyp(int)
#
# ~/Documents/Personal/DATA-ANALYSIS-ML-AI/Data-Analysis-ML-AI/da_env/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# ...

# %% [markdown]
# ## Manipulating Data

# %% [markdown]
# ## Manipulating Data

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# We can also fill data w/o having to reassign it 
# car_sales_missing["Doors"].fillna(car_sales_missing["Doors"].mean(), 
#                                     inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    4.0      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
# Dropping the data with NaN value .dropna(inplace=True) 

car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.000000    4.0   $4,000    5.0
# 1   Honda    Red   87899.000000    4.0   $5,000    4.0
# 2  Toyota   Blue   92302.666667    3.0   $7,000    5.0
# 3     BMW  Black   11179.000000    5.0  $22,000    NaN
# 4  Nissan  White  213095.000000    4.0   $3,500    NaN
# 5  Toyota  Green   92302.666667    4.0   $4,500    NaN

# %%
# Creating Data: New Columns (from Series)
seat_column = pd.Series([5,4,5])

# %%
car_sales_missing["Seats"] = seat_column

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.000000    4.0   $4,000    5.0
# 1   Honda    Red   87899.000000    4.0   $5,000    4.0
# 2  Toyota   Blue   92302.666667    3.0   $7,000    5.0
# 3     BMW  Black   11179.000000    5.0  $22,000    NaN
# 4  Nissan  White  213095.000000    4.0   $3,500    NaN
# 5  Toyota  Green   92302.666667    4.0   $4,500    NaN

# %%
# Filling the NaN with value 

car_sales_missing["Seats"].fillna(2, inplace=True)
# Out:
# /tmp/ipykernel_35419/2593364456.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales_missing["Seats"].fillna(2, inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.000000    4.0   $4,000    5.0
# 1   Honda    Red   87899.000000    4.0   $5,000    4.0
# 2  Toyota   Blue   92302.666667    3.0   $7,000    5.0
# 3     BMW  Black   11179.000000    5.0  $22,000    2.0
# 4  Nissan  White  213095.000000    4.0   $3,500    2.0
# 5  Toyota  Green   92302.666667    4.0   $4,500    2.0

# %%
# Column from Python List 

fuel_economy = [8.2,2.5,6.8,10.88, 12.22,20.5]

# %%
car_sales_missing["Fuel Economy"] = fuel_economy

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Fuel Economy
# 0  Toyota  White  150043.000000    4.0   $4,000    5.0          8.20
# 1   Honda    Red   87899.000000    4.0   $5,000    4.0          2.50
# 2  Toyota   Blue   92302.666667    3.0   $7,000    5.0          6.80
# 3     BMW  Black   11179.000000    5.0  $22,000    2.0         10.88
# 4  Nissan  White  213095.000000    4.0   $3,500    2.0         12.22
# 5  Toyota  Green   92302.666667    4.0   $4,500    2.0         20.50

# %%
# Creating data column from the data 

car_sales_missing["Fuel Used"] = (car_sales_missing["Odometer"] / 100) *  car_sales_missing["Fuel Economy"]

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Fuel Economy  \
# 0  Toyota  White  150043.000000    4.0   $4,000    5.0          8.20
# 1   Honda    Red   87899.000000    4.0   $5,000    4.0          2.50
# 2  Toyota   Blue   92302.666667    3.0   $7,000    5.0          6.80
# 3     BMW  Black   11179.000000    5.0  $22,000    2.0         10.88
# 4  Nissan  White  213095.000000    4.0   $3,500    2.0         12.22
# 5  Toyota  Green   92302.666667    4.0   $4,500    2.0         20.50
#
#       Fuel Used
# 0  12303.526000
# 1   2197.475000
# 2   6276.581333
# 3   1216.275200
# 4  26040.209000
# 5  18922.046667

# %%
# Creating column from single value 

car_sales_missing["Wheels Number"] = 4
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Fuel Economy  \
# 0  Toyota  White  150043.000000    4.0   $4,000    5.0          8.20
# 1   Honda    Red   87899.000000    4.0   $5,000    4.0          2.50
# 2  Toyota   Blue   92302.666667    3.0   $7,000    5.0          6.80
# 3     BMW  Black   11179.000000    5.0  $22,000    2.0         10.88
# 4  Nissan  White  213095.000000    4.0   $3,500    2.0         12.22
# 5  Toyota  Green   92302.666667    4.0   $4,500    2.0         20.50
#
#       Fuel Used  Wheels Number
# 0  12303.526000              4
# 1   2197.475000              4
# 2   6276.581333              4
# 3   1216.275200              4
# 4  26040.209000              4
# 5  18922.046667              4

# %%
car_sales_missing["Road Safety"] = True
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Fuel Economy  \
# 0  Toyota  White  150043.000000    4.0   $4,000    5.0          8.20
# 1   Honda    Red   87899.000000    4.0   $5,000    4.0          2.50
# 2  Toyota   Blue   92302.666667    3.0   $7,000    5.0          6.80
# 3     BMW  Black   11179.000000    5.0  $22,000    2.0         10.88
# 4  Nissan  White  213095.000000    4.0   $3,500    2.0         12.22
# 5  Toyota  Green   92302.666667    4.0   $4,500    2.0         20.50
#
#       Fuel Used  Wheels Number  Road Safety
# 0  12303.526000              4         True
# 1   2197.475000              4         True
# 2   6276.581333              4         True
# 3   1216.275200              4         True
# 4  26040.209000              4         True
# 5  18922.046667              4         True

# %%
car_sales_missing["Random Column"] = 100
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Fuel Economy  \
# 0  Toyota  White  150043.000000    4.0   $4,000    5.0          8.20
# 1   Honda    Red   87899.000000    4.0   $5,000    4.0          2.50
# 2  Toyota   Blue   92302.666667    3.0   $7,000    5.0          6.80
# 3     BMW  Black   11179.000000    5.0  $22,000    2.0         10.88
# 4  Nissan  White  213095.000000    4.0   $3,500    2.0         12.22
# 5  Toyota  Green   92302.666667    4.0   $4,500    2.0         20.50
#
#       Fuel Used  Wheels Number  Road Safety  Random Column
# 0  12303.526000              4         True            100
# 1   2197.475000              4         True            100
# 2   6276.581333              4         True            100
# 3   1216.275200              4         True            100
# 4  26040.209000              4         True            100
# 5  18922.046667              4         True            100

# %%
car_sales_missing = car_sales_missing.drop("Random Column", axis=1)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Fuel Economy  \
# 0  Toyota  White  150043.000000    4.0   $4,000    5.0          8.20
# 1   Honda    Red   87899.000000    4.0   $5,000    4.0          2.50
# 2  Toyota   Blue   92302.666667    3.0   $7,000    5.0          6.80
# 3     BMW  Black   11179.000000    5.0  $22,000    2.0         10.88
# 4  Nissan  White  213095.000000    4.0   $3,500    2.0         12.22
# 5  Toyota  Green   92302.666667    4.0   $4,500    2.0         20.50
#
#       Fuel Used  Wheels Number  Road Safety
# 0  12303.526000              4         True
# 1   2197.475000              4         True
# 2   6276.581333              4         True
# 3   1216.275200              4         True
# 4  26040.209000              4         True
# 5  18922.046667              4         True
